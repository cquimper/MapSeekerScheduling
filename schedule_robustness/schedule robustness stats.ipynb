# %%
import pandas as pd
import numpy as np
from collections import OrderedDict

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
path = '/content/drive/My Drive/Colab Notebooks/schedule_robustness/'
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv(path + 'stats.csv')
df
# Out:
#                             table_name  noise_columns  nb_rows task_option  \
# 0      schedule_robustness_a_a_b_a_a_0              0       10           a
# 1      schedule_robustness_a_a_b_a_a_1              0       10           a
# 2      schedule_robustness_a_a_b_a_a_2              0       10           a
# 3      schedule_robustness_a_a_b_a_a_3              0       10           a
# 4      schedule_robustness_a_a_b_a_a_4              0       10           a
# ...                                ...            ...      ...         ...
# 47995  schedule_robustness_h_q_e_b_d_5              1    10000           h
# 47996  schedule_robustness_h_q_e_b_d_6              1    10000           h
# 47997  schedule_robustness_h_q_e_b_d_7              1    10000           h
# 47998  schedule_robustness_h_q_e_b_d_8              1    10000           h
# 47999  schedule_robustness_h_q_e_b_d_9              1    10000           h
#
#       temporal_option schedule_option noise_option entries_option  \
# ...

# %%
df.columns[:]
# Out:
# Index(['table_name', 'noise_columns', 'nb_rows', 'task_option',
#        'temporal_option', 'schedule_option', 'noise_option', 'entries_option',
#        'is_formula_end_time', 'is_formula_duration', 'is_precedence',
#        'is_schedule_resource_disj', 'is_schedule_resource_diffn',
#        'is_schedule_calendar_shift', 'is_schedule_calendar_cal',
#        'found_formula_exact_end_time', 'found_formula_partial_end_time',
#        'found_extra_formulae_end_time', 'found_formula_exact_duration',
#        'found_formula_partial_duration', 'found_extra_formulae_duration',
#        'found_exact_precedence', 'found_partial_precedence',
#        'found_extra_precedence', 'found_exact_schedule_resource_disj',
#        'found_partial_schedule_resource_disj',
#        'found_extra_schedule_resource_disj',
#        'found_exact_schedule_resource_diffn',
#        'found_partial_schedule_resource_diffn',
#        'found_extra_schedule_resource_diffn',
# ...

# %%
total_is_precedence = 0
total_found_exact_precedence = 0
total_found_partial_precedence = 0
total_found_extra_precedence = 0

for i in range(0,len(df)):
  total_is_precedence += df['is_precedence'][i]
  total_found_exact_precedence += df['found_exact_precedence'][i]
  total_found_partial_precedence += df['found_partial_precedence'][i]
  total_found_extra_precedence += df['found_extra_precedence'][i]
print('ALL DATA')
print('to find precedence ctr          : ' + str(total_is_precedence))
print('  found precedence ctr (exact)  : ' + str(total_found_exact_precedence) + '. Ratio is ' + str(total_found_exact_precedence / total_is_precedence))
print('  found precedence ctr (partial): ' + str(total_found_partial_precedence) + '. Ratio is ' + str(total_found_partial_precedence / total_is_precedence))
print('  found precedence ctr (extra)  : ' + str(total_found_extra_precedence) + '. Ratio is ' + str(total_found_extra_precedence / total_is_precedence))

total_is_precedence = 0
total_found_exact_precedence = 0
total_found_partial_precedence = 0
total_found_extra_precedence = 0

for i in range(0,len(df)):
  if df['noise_columns'][i] == 0:
    total_is_precedence += df['is_precedence'][i]
    total_found_exact_precedence += df['found_exact_precedence'][i]
    total_found_partial_precedence += df['found_partial_precedence'][i]
    total_found_extra_precedence += df['found_extra_precedence'][i]
print('WITHOUT NOISE')
print('to find precedence ctr          : ' + str(total_is_precedence))
print('  found precedence ctr (exact)  : ' + str(total_found_exact_precedence) + '. Ratio is ' + str(total_found_exact_precedence / total_is_precedence))
print('  found precedence ctr (partial): ' + str(total_found_partial_precedence) + '. Ratio is ' + str(total_found_partial_precedence / total_is_precedence))
print('  found precedence ctr (extra)  : ' + str(total_found_extra_precedence) + '. Ratio is ' + str(total_found_extra_precedence / total_is_precedence))

total_is_precedence = 0
total_found_exact_precedence = 0
total_found_partial_precedence = 0
total_found_extra_precedence = 0

for i in range(0,len(df)):
  if df['noise_columns'][i] == 1:
    total_is_precedence += df['is_precedence'][i]
    total_found_exact_precedence += df['found_exact_precedence'][i]
    total_found_partial_precedence += df['found_partial_precedence'][i]
    total_found_extra_precedence += df['found_extra_precedence'][i]
print('WITH NOISE')
print('to find precedence ctr          : ' + str(total_is_precedence))
print('  found precedence ctr (exact)  : ' + str(total_found_exact_precedence) + '. Ratio is ' + str(total_found_exact_precedence / total_is_precedence))
print('  found precedence ctr (partial): ' + str(total_found_partial_precedence) + '. Ratio is ' + str(total_found_partial_precedence / total_is_precedence))
print('  found precedence ctr (extra)  : ' + str(total_found_extra_precedence) + '. Ratio is ' + str(total_found_extra_precedence / total_is_precedence))

total_is_precedence = 0
total_found_exact_precedence = 0
total_found_partial_precedence = 0
total_found_extra_precedence = 0

for i in range(0,len(df)):
  if df['nb_rows'][i] == 10:
    total_is_precedence += df['is_precedence'][i]
    total_found_exact_precedence += df['found_exact_precedence'][i]
    total_found_partial_precedence += df['found_partial_precedence'][i]
    total_found_extra_precedence += df['found_extra_precedence'][i]
print('Nb ROWS = 10')
print('to find precedence ctr          : ' + str(total_is_precedence))
print('  found precedence ctr (exact)  : ' + str(total_found_exact_precedence) + '. Ratio is ' + str(total_found_exact_precedence / total_is_precedence))
print('  found precedence ctr (partial): ' + str(total_found_partial_precedence) + '. Ratio is ' + str(total_found_partial_precedence / total_is_precedence))
print('  found precedence ctr (extra)  : ' + str(total_found_extra_precedence) + '. Ratio is ' + str(total_found_extra_precedence / total_is_precedence))

total_is_precedence = 0
total_found_exact_precedence = 0
total_found_partial_precedence = 0
total_found_extra_precedence = 0

for i in range(0,len(df)):
  if df['nb_rows'][i] == 100:
    total_is_precedence += df['is_precedence'][i]
    total_found_exact_precedence += df['found_exact_precedence'][i]
    total_found_partial_precedence += df['found_partial_precedence'][i]
    total_found_extra_precedence += df['found_extra_precedence'][i]
print('Nb ROWS = 100')
print('to find precedence ctr          : ' + str(total_is_precedence))
print('  found precedence ctr (exact)  : ' + str(total_found_exact_precedence) + '. Ratio is ' + str(total_found_exact_precedence / total_is_precedence))
print('  found precedence ctr (partial): ' + str(total_found_partial_precedence) + '. Ratio is ' + str(total_found_partial_precedence / total_is_precedence))
print('  found precedence ctr (extra)  : ' + str(total_found_extra_precedence) + '. Ratio is ' + str(total_found_extra_precedence / total_is_precedence))

total_is_precedence = 0
total_found_exact_precedence = 0
total_found_partial_precedence = 0
total_found_extra_precedence = 0

for i in range(0,len(df)):
  if df['nb_rows'][i] == 1000:
    total_is_precedence += df['is_precedence'][i]
    total_found_exact_precedence += df['found_exact_precedence'][i]
    total_found_partial_precedence += df['found_partial_precedence'][i]
    total_found_extra_precedence += df['found_extra_precedence'][i]
print('Nb ROWS = 1000')
print('to find precedence ctr          : ' + str(total_is_precedence))
print('  found precedence ctr (exact)  : ' + str(total_found_exact_precedence) + '. Ratio is ' + str(total_found_exact_precedence / total_is_precedence))
print('  found precedence ctr (partial): ' + str(total_found_partial_precedence) + '. Ratio is ' + str(total_found_partial_precedence / total_is_precedence))
print('  found precedence ctr (extra)  : ' + str(total_found_extra_precedence) + '. Ratio is ' + str(total_found_extra_precedence / total_is_precedence))

total_is_precedence = 0
total_found_exact_precedence = 0
total_found_partial_precedence = 0
total_found_extra_precedence = 0

for i in range(0,len(df)):
  if df['nb_rows'][i] == 10000:
    total_is_precedence += df['is_precedence'][i]
    total_found_exact_precedence += df['found_exact_precedence'][i]
    total_found_partial_precedence += df['found_partial_precedence'][i]
    total_found_extra_precedence += df['found_extra_precedence'][i]
print('Nb ROWS = 10000')
print('to find precedence ctr          : ' + str(total_is_precedence))
print('  found precedence ctr (exact)  : ' + str(total_found_exact_precedence) + '. Ratio is ' + str(total_found_exact_precedence / total_is_precedence))
print('  found precedence ctr (partial): ' + str(total_found_partial_precedence) + '. Ratio is ' + str(total_found_partial_precedence / total_is_precedence))
print('  found precedence ctr (extra)  : ' + str(total_found_extra_precedence) + '. Ratio is ' + str(total_found_extra_precedence / total_is_precedence))
# Out:
# ALL DATA
# to find precedence ctr          : 43840
#   found precedence ctr (exact)  : 21150. Ratio is 0.4824361313868613
#   found precedence ctr (partial): 17510. Ratio is 0.3994069343065693
#   found precedence ctr (extra)  : 1727. Ratio is 0.03939324817518248
# WITHOUT NOISE
# to find precedence ctr          : 21920
#   found precedence ctr (exact)  : 10639. Ratio is 0.4853558394160584
#   found precedence ctr (partial): 8512. Ratio is 0.3883211678832117
#   found precedence ctr (extra)  : 1061. Ratio is 0.04840328467153285
# WITH NOISE
# to find precedence ctr          : 21920
#   found precedence ctr (exact)  : 10511. Ratio is 0.47951642335766426
#   found precedence ctr (partial): 8998. Ratio is 0.410492700729927
#   found precedence ctr (extra)  : 666. Ratio is 0.030383211678832116
# Nb ROWS = 10
# to find precedence ctr          : 10960
#   found precedence ctr (exact)  : 3608. Ratio is 0.3291970802919708
#   found precedence ctr (partial): 5833. Ratio is 0.5322080291970803
# ...

# %%
total_is_resource_disj = 0
total_found_exact_resource_disj = 0
total_found_partial_resource_disj = 0
total_found_extra_resource_disj = 0

for i in range(0,len(df)):
  total_is_resource_disj += df['is_schedule_resource_disj'][i]
  total_found_exact_resource_disj += df['found_exact_schedule_resource_disj'][i]
  total_found_partial_resource_disj += df['found_partial_schedule_resource_disj'][i]
  total_found_extra_resource_disj += df['found_extra_schedule_resource_disj'][i]
print('ALL DATA')
print('to find resource DISJUNCTIVE ctr          : ' + str(total_is_resource_disj))
print('  found resource DISJUNCTIVE ctr (exact)  : ' + str(total_found_exact_resource_disj) + '. Ratio is ' + str(total_found_exact_resource_disj / total_is_resource_disj))
print('  found resource DISJUNCTIVE ctr (partial): ' + str(total_found_partial_resource_disj) + '. Ratio is ' + str(total_found_partial_resource_disj / total_is_resource_disj))
print('  found resource DISJUNCTIVE ctr (extra)  : ' + str(total_found_extra_resource_disj) + '. Ratio is ' + str(total_found_extra_resource_disj / total_is_resource_disj))

total_is_resource_disj = 0
total_found_exact_resource_disj = 0
total_found_partial_resource_disj = 0
total_found_extra_resource_disj = 0

for i in range(0,len(df)):
  if df['noise_columns'][i] == 0:
    total_is_resource_disj += df['is_schedule_resource_disj'][i]
    total_found_exact_resource_disj += df['found_exact_schedule_resource_disj'][i]
    total_found_partial_resource_disj += df['found_partial_schedule_resource_disj'][i]
    total_found_extra_resource_disj += df['found_extra_schedule_resource_disj'][i]
print('WITHOUT NOISE')
print('to find resource DISJUNCTIVE ctr          : ' + str(total_is_resource_disj))
print('  found resource DISJUNCTIVE ctr (exact)  : ' + str(total_found_exact_resource_disj) + '. Ratio is ' + str(total_found_exact_resource_disj / total_is_resource_disj))
print('  found resource DISJUNCTIVE ctr (partial): ' + str(total_found_partial_resource_disj) + '. Ratio is ' + str(total_found_partial_resource_disj / total_is_resource_disj))
print('  found resource DISJUNCTIVE ctr (extra)  : ' + str(total_found_extra_resource_disj) + '. Ratio is ' + str(total_found_extra_resource_disj / total_is_resource_disj))

total_is_resource_disj = 0
total_found_exact_resource_disj = 0
total_found_partial_resource_disj = 0
total_found_extra_resource_disj = 0

for i in range(0,len(df)):
  if df['noise_columns'][i] == 1:
    total_is_resource_disj += df['is_schedule_resource_disj'][i]
    total_found_exact_resource_disj += df['found_exact_schedule_resource_disj'][i]
    total_found_partial_resource_disj += df['found_partial_schedule_resource_disj'][i]
    total_found_extra_resource_disj += df['found_extra_schedule_resource_disj'][i]
print('WITH NOISE')
print('to find resource DISJUNCTIVE ctr          : ' + str(total_is_resource_disj))
print('  found resource DISJUNCTIVE ctr (exact)  : ' + str(total_found_exact_resource_disj) + '. Ratio is ' + str(total_found_exact_resource_disj / total_is_resource_disj))
print('  found resource DISJUNCTIVE ctr (partial): ' + str(total_found_partial_resource_disj) + '. Ratio is ' + str(total_found_partial_resource_disj / total_is_resource_disj))
print('  found resource DISJUNCTIVE ctr (extra)  : ' + str(total_found_extra_resource_disj) + '. Ratio is ' + str(total_found_extra_resource_disj / total_is_resource_disj))

total_is_resource_disj = 0
total_found_exact_resource_disj = 0
total_found_partial_resource_disj = 0
total_found_extra_resource_disj = 0

for i in range(0,len(df)):
  if df['nb_rows'][i] == 10:
    total_is_resource_disj += df['is_schedule_resource_disj'][i]
    total_found_exact_resource_disj += df['found_exact_schedule_resource_disj'][i]
    total_found_partial_resource_disj += df['found_partial_schedule_resource_disj'][i]
    total_found_extra_resource_disj += df['found_extra_schedule_resource_disj'][i]

print('Nb ROWS = 10')
print('to find resource DISJUNCTIVE ctr          : ' + str(total_is_resource_disj))
print('  found resource DISJUNCTIVE ctr (exact)  : ' + str(total_found_exact_resource_disj) + '. Ratio is ' + str(total_found_exact_resource_disj / total_is_resource_disj))
print('  found resource DISJUNCTIVE ctr (partial): ' + str(total_found_partial_resource_disj) + '. Ratio is ' + str(total_found_partial_resource_disj / total_is_resource_disj))
print('  found resource DISJUNCTIVE ctr (extra)  : ' + str(total_found_extra_resource_disj) + '. Ratio is ' + str(total_found_extra_resource_disj / total_is_resource_disj))

total_is_resource_disj = 0
total_found_exact_resource_disj = 0
total_found_partial_resource_disj = 0
total_found_extra_resource_disj = 0

for i in range(0,len(df)):
  if df['nb_rows'][i] == 100:
    total_is_resource_disj += df['is_schedule_resource_disj'][i]
    total_found_exact_resource_disj += df['found_exact_schedule_resource_disj'][i]
    total_found_partial_resource_disj += df['found_partial_schedule_resource_disj'][i]
    total_found_extra_resource_disj += df['found_extra_schedule_resource_disj'][i]
print('Nb ROWS = 100')
print('to find resource DISJUNCTIVE ctr          : ' + str(total_is_resource_disj))
print('  found resource DISJUNCTIVE ctr (exact)  : ' + str(total_found_exact_resource_disj) + '. Ratio is ' + str(total_found_exact_resource_disj / total_is_resource_disj))
print('  found resource DISJUNCTIVE ctr (partial): ' + str(total_found_partial_resource_disj) + '. Ratio is ' + str(total_found_partial_resource_disj / total_is_resource_disj))
print('  found resource DISJUNCTIVE ctr (extra)  : ' + str(total_found_extra_resource_disj) + '. Ratio is ' + str(total_found_extra_resource_disj / total_is_resource_disj))

total_is_resource_disj = 0
total_found_exact_resource_disj = 0
total_found_partial_resource_disj = 0
total_found_extra_resource_disj = 0

for i in range(0,len(df)):
  if df['nb_rows'][i] == 1000:
    total_is_resource_disj += df['is_schedule_resource_disj'][i]
    total_found_exact_resource_disj += df['found_exact_schedule_resource_disj'][i]
    total_found_partial_resource_disj += df['found_partial_schedule_resource_disj'][i]
    total_found_extra_resource_disj += df['found_extra_schedule_resource_disj'][i]
print('Nb ROWS = 1000')
print('to find resource DISJUNCTIVE ctr          : ' + str(total_is_resource_disj))
print('  found resource DISJUNCTIVE ctr (exact)  : ' + str(total_found_exact_resource_disj) + '. Ratio is ' + str(total_found_exact_resource_disj / total_is_resource_disj))
print('  found resource DISJUNCTIVE ctr (partial): ' + str(total_found_partial_resource_disj) + '. Ratio is ' + str(total_found_partial_resource_disj / total_is_resource_disj))
print('  found resource DISJUNCTIVE ctr (extra)  : ' + str(total_found_extra_resource_disj) + '. Ratio is ' + str(total_found_extra_resource_disj / total_is_resource_disj))

total_is_resource_disj = 0
total_found_exact_resource_disj = 0
total_found_partial_resource_disj = 0
total_found_extra_resource_disj = 0

for i in range(0,len(df)):
  if df['nb_rows'][i] == 10000:
    total_is_resource_disj += df['is_schedule_resource_disj'][i]
    total_found_exact_resource_disj += df['found_exact_schedule_resource_disj'][i]
    total_found_partial_resource_disj += df['found_partial_schedule_resource_disj'][i]
    total_found_extra_resource_disj += df['found_extra_schedule_resource_disj'][i]
print('Nb ROWS = 10000')
print('to find resource DISJUNCTIVE ctr          : ' + str(total_is_resource_disj))
print('  found resource DISJUNCTIVE ctr (exact)  : ' + str(total_found_exact_resource_disj) + '. Ratio is ' + str(total_found_exact_resource_disj / total_is_resource_disj))
print('  found resource DISJUNCTIVE ctr (partial): ' + str(total_found_partial_resource_disj) + '. Ratio is ' + str(total_found_partial_resource_disj / total_is_resource_disj))
print('  found resource DISJUNCTIVE ctr (extra)  : ' + str(total_found_extra_resource_disj) + '. Ratio is ' + str(total_found_extra_resource_disj / total_is_resource_disj))
# Out:
# ALL DATA
# to find resource DISJUNCTIVE ctr          : 11520
#   found resource DISJUNCTIVE ctr (exact)  : 11385. Ratio is 0.98828125
#   found resource DISJUNCTIVE ctr (partial): 0. Ratio is 0.0
#   found resource DISJUNCTIVE ctr (extra)  : 20. Ratio is 0.001736111111111111
# WITHOUT NOISE
# to find resource DISJUNCTIVE ctr          : 5760
#   found resource DISJUNCTIVE ctr (exact)  : 5669. Ratio is 0.9842013888888889
#   found resource DISJUNCTIVE ctr (partial): 0. Ratio is 0.0
#   found resource DISJUNCTIVE ctr (extra)  : 0. Ratio is 0.0
# WITH NOISE
# to find resource DISJUNCTIVE ctr          : 5760
#   found resource DISJUNCTIVE ctr (exact)  : 5716. Ratio is 0.9923611111111111
#   found resource DISJUNCTIVE ctr (partial): 0. Ratio is 0.0
#   found resource DISJUNCTIVE ctr (extra)  : 20. Ratio is 0.003472222222222222
# Nb ROWS = 10
# to find resource DISJUNCTIVE ctr          : 2880
#   found resource DISJUNCTIVE ctr (exact)  : 2768. Ratio is 0.9611111111111111
# ...

# %%
total_is_resource_diffn = 0
total_found_exact_resource_diffn = 0
total_found_partial_resource_diffn = 0
total_found_extra_resource_diffn = 0

for i in range(0,len(df)):
  total_is_resource_diffn += df['is_schedule_resource_diffn'][i]
  total_found_exact_resource_diffn += df['found_exact_schedule_resource_diffn'][i]
  total_found_partial_resource_diffn += df['found_partial_schedule_resource_diffn'][i]
  total_found_extra_resource_diffn += df['found_extra_schedule_resource_diffn'][i]
print('ALL DATA')
print('to find resource DIFFN ctr          : ' + str(total_is_resource_diffn))
print('  found resource DIFFN ctr (exact)  : ' + str(total_found_exact_resource_diffn) + '. Ratio is ' + str(total_found_exact_resource_diffn / total_is_resource_diffn))
print('  found resource DIFFN ctr (partial): ' + str(total_found_partial_resource_diffn) + '. Ratio is ' + str(total_found_partial_resource_diffn / total_is_resource_diffn))
print('  found resource DIFFN ctr (extra)  : ' + str(total_found_extra_resource_diffn) + '. Ratio is ' + str(total_found_extra_resource_diffn / total_is_resource_diffn))

total_is_resource_diffn = 0
total_found_exact_resource_diffn = 0
total_found_partial_resource_diffn = 0
total_found_extra_resource_diffn = 0

for i in range(0,len(df)):
  if df['noise_columns'][i] == 0:
    total_is_resource_diffn += df['is_schedule_resource_diffn'][i]
    total_found_exact_resource_diffn += df['found_exact_schedule_resource_diffn'][i]
    total_found_partial_resource_diffn += df['found_partial_schedule_resource_diffn'][i]
    total_found_extra_resource_diffn += df['found_extra_schedule_resource_diffn'][i]
print('WITHOUT NOISE')
print('to find resource DIFFN ctr          : ' + str(total_is_resource_diffn))
print('  found resource DIFFN ctr (exact)  : ' + str(total_found_exact_resource_diffn) + '. Ratio is ' + str(total_found_exact_resource_diffn / total_is_resource_diffn))
print('  found resource DIFFN ctr (partial): ' + str(total_found_partial_resource_diffn) + '. Ratio is ' + str(total_found_partial_resource_diffn / total_is_resource_diffn))
print('  found resource DIFFN ctr (extra)  : ' + str(total_found_extra_resource_diffn) + '. Ratio is ' + str(total_found_extra_resource_diffn / total_is_resource_diffn))

total_is_resource_diffn = 0
total_found_exact_resource_diffn = 0
total_found_partial_resource_diffn = 0
total_found_extra_resource_diffn = 0

for i in range(0,len(df)):
  if df['noise_columns'][i] == 1:
    total_is_resource_diffn += df['is_schedule_resource_diffn'][i]
    total_found_exact_resource_diffn += df['found_exact_schedule_resource_diffn'][i]
    total_found_partial_resource_diffn += df['found_partial_schedule_resource_diffn'][i]
    total_found_extra_resource_diffn += df['found_extra_schedule_resource_diffn'][i]
print('WITH NOISE')
print('to find resource DIFFN ctr          : ' + str(total_is_resource_diffn))
print('  found resource DIFFN ctr (exact)  : ' + str(total_found_exact_resource_diffn) + '. Ratio is ' + str(total_found_exact_resource_diffn / total_is_resource_diffn))
print('  found resource DIFFN ctr (partial): ' + str(total_found_partial_resource_diffn) + '. Ratio is ' + str(total_found_partial_resource_diffn / total_is_resource_diffn))
print('  found resource DIFFN ctr (extra)  : ' + str(total_found_extra_resource_diffn) + '. Ratio is ' + str(total_found_extra_resource_diffn / total_is_resource_diffn))

total_is_resource_diffn = 0
total_found_exact_resource_diffn = 0
total_found_partial_resource_diffn = 0
total_found_extra_resource_diffn = 0

for i in range(0,len(df)):
  if df['nb_rows'][i] == 10:
    total_is_resource_diffn += df['is_schedule_resource_diffn'][i]
    total_found_exact_resource_diffn += df['found_exact_schedule_resource_diffn'][i]
    total_found_partial_resource_diffn += df['found_partial_schedule_resource_diffn'][i]
    total_found_extra_resource_diffn += df['found_extra_schedule_resource_diffn'][i]
print('Nb ROWS = 10')
print('to find resource DIFFN ctr          : ' + str(total_is_resource_diffn))
print('  found resource DIFFN ctr (exact)  : ' + str(total_found_exact_resource_diffn) + '. Ratio is ' + str(total_found_exact_resource_diffn / total_is_resource_diffn))
print('  found resource DIFFN ctr (partial): ' + str(total_found_partial_resource_diffn) + '. Ratio is ' + str(total_found_partial_resource_diffn / total_is_resource_diffn))
print('  found resource DIFFN ctr (extra)  : ' + str(total_found_extra_resource_diffn) + '. Ratio is ' + str(total_found_extra_resource_diffn / total_is_resource_diffn))

total_is_resource_diffn = 0
total_found_exact_resource_diffn = 0
total_found_partial_resource_diffn = 0
total_found_extra_resource_diffn = 0

for i in range(0,len(df)):
  if df['nb_rows'][i] == 100:
    total_is_resource_diffn += df['is_schedule_resource_diffn'][i]
    total_found_exact_resource_diffn += df['found_exact_schedule_resource_diffn'][i]
    total_found_partial_resource_diffn += df['found_partial_schedule_resource_diffn'][i]
    total_found_extra_resource_diffn += df['found_extra_schedule_resource_diffn'][i]
print('Nb ROWS = 100')
print('to find resource DIFFN ctr          : ' + str(total_is_resource_diffn))
print('  found resource DIFFN ctr (exact)  : ' + str(total_found_exact_resource_diffn) + '. Ratio is ' + str(total_found_exact_resource_diffn / total_is_resource_diffn))
print('  found resource DIFFN ctr (partial): ' + str(total_found_partial_resource_diffn) + '. Ratio is ' + str(total_found_partial_resource_diffn / total_is_resource_diffn))
print('  found resource DIFFN ctr (extra)  : ' + str(total_found_extra_resource_diffn) + '. Ratio is ' + str(total_found_extra_resource_diffn / total_is_resource_diffn))

total_is_resource_diffn = 0
total_found_exact_resource_diffn = 0
total_found_partial_resource_diffn = 0
total_found_extra_resource_diffn = 0

for i in range(0,len(df)):
  if df['nb_rows'][i] == 1000:
    total_is_resource_diffn += df['is_schedule_resource_diffn'][i]
    total_found_exact_resource_diffn += df['found_exact_schedule_resource_diffn'][i]
    total_found_partial_resource_diffn += df['found_partial_schedule_resource_diffn'][i]
    total_found_extra_resource_diffn += df['found_extra_schedule_resource_diffn'][i]
print('Nb ROWS = 1000')
print('to find resource DIFFN ctr          : ' + str(total_is_resource_diffn))
print('  found resource DIFFN ctr (exact)  : ' + str(total_found_exact_resource_diffn) + '. Ratio is ' + str(total_found_exact_resource_diffn / total_is_resource_diffn))
print('  found resource DIFFN ctr (partial): ' + str(total_found_partial_resource_diffn) + '. Ratio is ' + str(total_found_partial_resource_diffn / total_is_resource_diffn))
print('  found resource DIFFN ctr (extra)  : ' + str(total_found_extra_resource_diffn) + '. Ratio is ' + str(total_found_extra_resource_diffn / total_is_resource_diffn))

total_is_resource_diffn = 0
total_found_exact_resource_diffn = 0
total_found_partial_resource_diffn = 0
total_found_extra_resource_diffn = 0

for i in range(0,len(df)):
  if df['nb_rows'][i] == 10000:
    total_is_resource_diffn += df['is_schedule_resource_diffn'][i]
    total_found_exact_resource_diffn += df['found_exact_schedule_resource_diffn'][i]
    total_found_partial_resource_diffn += df['found_partial_schedule_resource_diffn'][i]
    total_found_extra_resource_diffn += df['found_extra_schedule_resource_diffn'][i]
print('Nb ROWS = 10000')
print('to find resource DIFFN ctr          : ' + str(total_is_resource_diffn))
print('  found resource DIFFN ctr (exact)  : ' + str(total_found_exact_resource_diffn) + '. Ratio is ' + str(total_found_exact_resource_diffn / total_is_resource_diffn))
print('  found resource DIFFN ctr (partial): ' + str(total_found_partial_resource_diffn) + '. Ratio is ' + str(total_found_partial_resource_diffn / total_is_resource_diffn))
print('  found resource DIFFN ctr (extra)  : ' + str(total_found_extra_resource_diffn) + '. Ratio is ' + str(total_found_extra_resource_diffn / total_is_resource_diffn))
# Out:
# ALL DATA
# to find resource DIFFN ctr          : 11520
#   found resource DIFFN ctr (exact)  : 11385. Ratio is 0.98828125
#   found resource DIFFN ctr (partial): 0. Ratio is 0.0
#   found resource DIFFN ctr (extra)  : 0. Ratio is 0.0
# WITHOUT NOISE
# to find resource DIFFN ctr          : 5760
#   found resource DIFFN ctr (exact)  : 5669. Ratio is 0.9842013888888889
#   found resource DIFFN ctr (partial): 0. Ratio is 0.0
#   found resource DIFFN ctr (extra)  : 0. Ratio is 0.0
# WITH NOISE
# to find resource DIFFN ctr          : 5760
#   found resource DIFFN ctr (exact)  : 5716. Ratio is 0.9923611111111111
#   found resource DIFFN ctr (partial): 0. Ratio is 0.0
#   found resource DIFFN ctr (extra)  : 0. Ratio is 0.0
# Nb ROWS = 10
# to find resource DIFFN ctr          : 2880
#   found resource DIFFN ctr (exact)  : 2768. Ratio is 0.9611111111111111
#   found resource DIFFN ctr (partial): 0. Ratio is 0.0
#   found resource DIFFN ctr (extra)  : 0. Ratio is 0.0
# Nb ROWS = 100
# ...

# %%
total_is_schedule_calendar_shift = 0
total_found_exact_schedule_calendar_shift = 0
total_found_partial_schedule_calendar_shift = 0
total_found_extra_schedule_calendar_shift = 0

for i in range(0,len(df)):
  total_is_schedule_calendar_shift += df['is_schedule_calendar_shift'][i]
  total_found_exact_schedule_calendar_shift += df['found_exact_schedule_calendar_shift'][i]
  total_found_partial_schedule_calendar_shift += df['found_partial_schedule_calendar_shift'][i]
  total_found_extra_schedule_calendar_shift += df['found_extra_schedule_calendar_shift'][i]
print('ALL DATA')
print('to find resource SHIFT ctr          : ' + str(total_is_schedule_calendar_shift))
print('  found resource SHIFT ctr (exact)  : ' + str(total_found_exact_schedule_calendar_shift) + '. Ratio is ' + str(total_found_exact_schedule_calendar_shift / total_is_schedule_calendar_shift))
print('  found resource SHIFT ctr (partial): ' + str(total_found_partial_schedule_calendar_shift) + '. Ratio is ' + str(total_found_partial_schedule_calendar_shift / total_is_schedule_calendar_shift))
print('  found resource SHIFT ctr (extra)  : ' + str(total_found_extra_schedule_calendar_shift) + '. Ratio is ' + str(total_found_extra_schedule_calendar_shift / total_is_schedule_calendar_shift))

total_is_schedule_calendar_shift = 0
total_found_exact_schedule_calendar_shift = 0
total_found_partial_schedule_calendar_shift = 0
total_found_extra_schedule_calendar_shift = 0

for i in range(0,len(df)):
  if df['noise_columns'][i] == 0:
    total_is_schedule_calendar_shift += df['is_schedule_calendar_shift'][i]
    total_found_exact_schedule_calendar_shift += df['found_exact_schedule_calendar_shift'][i]
    total_found_partial_schedule_calendar_shift += df['found_partial_schedule_calendar_shift'][i]
    total_found_extra_schedule_calendar_shift += df['found_extra_schedule_calendar_shift'][i]
print('WITHOUT NOISE')
print('to find resource SHIFT ctr          : ' + str(total_is_schedule_calendar_shift))
print('  found resource SHIFT ctr (exact)  : ' + str(total_found_exact_schedule_calendar_shift) + '. Ratio is ' + str(total_found_exact_schedule_calendar_shift / total_is_schedule_calendar_shift))
print('  found resource SHIFT ctr (partial): ' + str(total_found_partial_schedule_calendar_shift) + '. Ratio is ' + str(total_found_partial_schedule_calendar_shift / total_is_schedule_calendar_shift))
print('  found resource SHIFT ctr (extra)  : ' + str(total_found_extra_schedule_calendar_shift) + '. Ratio is ' + str(total_found_extra_schedule_calendar_shift / total_is_schedule_calendar_shift))

total_is_schedule_calendar_shift = 0
total_found_exact_schedule_calendar_shift = 0
total_found_partial_schedule_calendar_shift = 0
total_found_extra_schedule_calendar_shift = 0

for i in range(0,len(df)):
  if df['noise_columns'][i] == 1:
    total_is_schedule_calendar_shift += df['is_schedule_calendar_shift'][i]
    total_found_exact_schedule_calendar_shift += df['found_exact_schedule_calendar_shift'][i]
    total_found_partial_schedule_calendar_shift += df['found_partial_schedule_calendar_shift'][i]
    total_found_extra_schedule_calendar_shift += df['found_extra_schedule_calendar_shift'][i]
print('WITH NOISE')
print('to find resource SHIFT ctr          : ' + str(total_is_schedule_calendar_shift))
print('  found resource SHIFT ctr (exact)  : ' + str(total_found_exact_schedule_calendar_shift) + '. Ratio is ' + str(total_found_exact_schedule_calendar_shift / total_is_schedule_calendar_shift))
print('  found resource SHIFT ctr (partial): ' + str(total_found_partial_schedule_calendar_shift) + '. Ratio is ' + str(total_found_partial_schedule_calendar_shift / total_is_schedule_calendar_shift))
print('  found resource SHIFT ctr (extra)  : ' + str(total_found_extra_schedule_calendar_shift) + '. Ratio is ' + str(total_found_extra_schedule_calendar_shift / total_is_schedule_calendar_shift))

total_is_schedule_calendar_shift = 0
total_found_exact_schedule_calendar_shift = 0
total_found_partial_schedule_calendar_shift = 0
total_found_extra_schedule_calendar_shift = 0

for i in range(0,len(df)):
  if df['nb_rows'][i] == 10:
    total_is_schedule_calendar_shift += df['is_schedule_calendar_shift'][i]
    total_found_exact_schedule_calendar_shift += df['found_exact_schedule_calendar_shift'][i]
    total_found_partial_schedule_calendar_shift += df['found_partial_schedule_calendar_shift'][i]
    total_found_extra_schedule_calendar_shift += df['found_extra_schedule_calendar_shift'][i]
print('Nb ROWS = 10')
print('to find resource SHIFT ctr          : ' + str(total_is_schedule_calendar_shift))
print('  found resource SHIFT ctr (exact)  : ' + str(total_found_exact_schedule_calendar_shift) + '. Ratio is ' + str(total_found_exact_schedule_calendar_shift / total_is_schedule_calendar_shift))
print('  found resource SHIFT ctr (partial): ' + str(total_found_partial_schedule_calendar_shift) + '. Ratio is ' + str(total_found_partial_schedule_calendar_shift / total_is_schedule_calendar_shift))
print('  found resource SHIFT ctr (extra)  : ' + str(total_found_extra_schedule_calendar_shift) + '. Ratio is ' + str(total_found_extra_schedule_calendar_shift / total_is_schedule_calendar_shift))

total_is_schedule_calendar_shift = 0
total_found_exact_schedule_calendar_shift = 0
total_found_partial_schedule_calendar_shift = 0
total_found_extra_schedule_calendar_shift = 0

for i in range(0,len(df)):
  if df['nb_rows'][i] == 100:
    total_is_schedule_calendar_shift += df['is_schedule_calendar_shift'][i]
    total_found_exact_schedule_calendar_shift += df['found_exact_schedule_calendar_shift'][i]
    total_found_partial_schedule_calendar_shift += df['found_partial_schedule_calendar_shift'][i]
    total_found_extra_schedule_calendar_shift += df['found_extra_schedule_calendar_shift'][i]
print('Nb ROWS = 100')
print('to find resource SHIFT ctr          : ' + str(total_is_schedule_calendar_shift))
print('  found resource SHIFT ctr (exact)  : ' + str(total_found_exact_schedule_calendar_shift) + '. Ratio is ' + str(total_found_exact_schedule_calendar_shift / total_is_schedule_calendar_shift))
print('  found resource SHIFT ctr (partial): ' + str(total_found_partial_schedule_calendar_shift) + '. Ratio is ' + str(total_found_partial_schedule_calendar_shift / total_is_schedule_calendar_shift))
print('  found resource SHIFT ctr (extra)  : ' + str(total_found_extra_schedule_calendar_shift) + '. Ratio is ' + str(total_found_extra_schedule_calendar_shift / total_is_schedule_calendar_shift))

total_is_schedule_calendar_shift = 0
total_found_exact_schedule_calendar_shift = 0
total_found_partial_schedule_calendar_shift = 0
total_found_extra_schedule_calendar_shift = 0

for i in range(0,len(df)):
  if df['nb_rows'][i] == 1000:
    total_is_schedule_calendar_shift += df['is_schedule_calendar_shift'][i]
    total_found_exact_schedule_calendar_shift += df['found_exact_schedule_calendar_shift'][i]
    total_found_partial_schedule_calendar_shift += df['found_partial_schedule_calendar_shift'][i]
    total_found_extra_schedule_calendar_shift += df['found_extra_schedule_calendar_shift'][i]
print('Nb ROWS = 1000')
print('to find resource SHIFT ctr          : ' + str(total_is_schedule_calendar_shift))
print('  found resource SHIFT ctr (exact)  : ' + str(total_found_exact_schedule_calendar_shift) + '. Ratio is ' + str(total_found_exact_schedule_calendar_shift / total_is_schedule_calendar_shift))
print('  found resource SHIFT ctr (partial): ' + str(total_found_partial_schedule_calendar_shift) + '. Ratio is ' + str(total_found_partial_schedule_calendar_shift / total_is_schedule_calendar_shift))
print('  found resource SHIFT ctr (extra)  : ' + str(total_found_extra_schedule_calendar_shift) + '. Ratio is ' + str(total_found_extra_schedule_calendar_shift / total_is_schedule_calendar_shift))

total_is_schedule_calendar_shift = 0
total_found_exact_schedule_calendar_shift = 0
total_found_partial_schedule_calendar_shift = 0
total_found_extra_schedule_calendar_shift = 0

for i in range(0,len(df)):
  if df['nb_rows'][i] == 10000:
    total_is_schedule_calendar_shift += df['is_schedule_calendar_shift'][i]
    total_found_exact_schedule_calendar_shift += df['found_exact_schedule_calendar_shift'][i]
    total_found_partial_schedule_calendar_shift += df['found_partial_schedule_calendar_shift'][i]
    total_found_extra_schedule_calendar_shift += df['found_extra_schedule_calendar_shift'][i]
print('Nb ROWS = 10000')
print('to find resource SHIFT ctr          : ' + str(total_is_schedule_calendar_shift))
print('  found resource SHIFT ctr (exact)  : ' + str(total_found_exact_schedule_calendar_shift) + '. Ratio is ' + str(total_found_exact_schedule_calendar_shift / total_is_schedule_calendar_shift))
print('  found resource SHIFT ctr (partial): ' + str(total_found_partial_schedule_calendar_shift) + '. Ratio is ' + str(total_found_partial_schedule_calendar_shift / total_is_schedule_calendar_shift))
print('  found resource SHIFT ctr (extra)  : ' + str(total_found_extra_schedule_calendar_shift) + '. Ratio is ' + str(total_found_extra_schedule_calendar_shift / total_is_schedule_calendar_shift))
# Out:
# ALL DATA
# to find resource SHIFT ctr          : 15840
#   found resource SHIFT ctr (exact)  : 15579. Ratio is 0.9835227272727273
#   found resource SHIFT ctr (partial): 99. Ratio is 0.00625
#   found resource SHIFT ctr (extra)  : 0. Ratio is 0.0
# WITHOUT NOISE
# to find resource SHIFT ctr          : 7920
#   found resource SHIFT ctr (exact)  : 7755. Ratio is 0.9791666666666666
#   found resource SHIFT ctr (partial): 59. Ratio is 0.00744949494949495
#   found resource SHIFT ctr (extra)  : 0. Ratio is 0.0
# WITH NOISE
# to find resource SHIFT ctr          : 7920
#   found resource SHIFT ctr (exact)  : 7824. Ratio is 0.9878787878787879
#   found resource SHIFT ctr (partial): 40. Ratio is 0.005050505050505051
#   found resource SHIFT ctr (extra)  : 0. Ratio is 0.0
# Nb ROWS = 10
# to find resource SHIFT ctr          : 3960
#   found resource SHIFT ctr (exact)  : 3787. Ratio is 0.9563131313131313
#   found resource SHIFT ctr (partial): 85. Ratio is 0.021464646464646464
# ...

# %%
total_is_schedule_calendar_cal = 0
total_found_exact_schedule_calendar_cal = 0
total_found_partial_schedule_calendar_cal = 0
total_found_extra_schedule_calendar_cal = 0

for i in range(0,len(df)):
  total_is_schedule_calendar_cal += df['is_schedule_calendar_cal'][i]
  total_found_exact_schedule_calendar_cal += df['found_exact_schedule_calendar_cal'][i]
  total_found_partial_schedule_calendar_cal += df['found_partial_schedule_calendar_cal'][i]
  total_found_extra_schedule_calendar_cal += df['found_extra_schedule_calendar_cal'][i]
print('ALL DATA')
print('to find resource CALENDAR ctr          : ' + str(total_is_schedule_calendar_cal))
print('  found resource CALENDAR ctr (exact)  : ' + str(total_found_exact_schedule_calendar_cal) + '. Ratio is ' + str(total_found_exact_schedule_calendar_cal / total_is_schedule_calendar_cal))
print('  found resource CALENDAR ctr (partial): ' + str(total_found_partial_schedule_calendar_cal) + '. Ratio is ' + str(total_found_partial_schedule_calendar_cal / total_is_schedule_calendar_cal))
print('  found resource CALENDAR ctr (extra)  : ' + str(total_found_extra_schedule_calendar_cal) + '. Ratio is ' + str(total_found_extra_schedule_calendar_cal / total_is_schedule_calendar_cal))

total_is_schedule_calendar_cal = 0
total_found_exact_schedule_calendar_cal = 0
total_found_partial_schedule_calendar_cal = 0
total_found_extra_schedule_calendar_cal = 0

for i in range(0,len(df)):
  if df['noise_columns'][i] == 0:
    total_is_schedule_calendar_cal += df['is_schedule_calendar_cal'][i]
    total_found_exact_schedule_calendar_cal += df['found_exact_schedule_calendar_cal'][i]
    total_found_partial_schedule_calendar_cal += df['found_partial_schedule_calendar_cal'][i]
    total_found_extra_schedule_calendar_cal += df['found_extra_schedule_calendar_cal'][i]
print('WITHOUT NOISE')
print('to find resource CALENDAR ctr          : ' + str(total_is_schedule_calendar_cal))
print('  found resource CALENDAR ctr (exact)  : ' + str(total_found_exact_schedule_calendar_cal) + '. Ratio is ' + str(total_found_exact_schedule_calendar_cal / total_is_schedule_calendar_cal))
print('  found resource CALENDAR ctr (partial): ' + str(total_found_partial_schedule_calendar_cal) + '. Ratio is ' + str(total_found_partial_schedule_calendar_cal / total_is_schedule_calendar_cal))
print('  found resource CALENDAR ctr (extra)  : ' + str(total_found_extra_schedule_calendar_cal) + '. Ratio is ' + str(total_found_extra_schedule_calendar_cal / total_is_schedule_calendar_cal))

total_is_schedule_calendar_cal = 0
total_found_exact_schedule_calendar_cal = 0
total_found_partial_schedule_calendar_cal = 0
total_found_extra_schedule_calendar_cal = 0

for i in range(0,len(df)):
  if df['noise_columns'][i] == 1:
    total_is_schedule_calendar_cal += df['is_schedule_calendar_cal'][i]
    total_found_exact_schedule_calendar_cal += df['found_exact_schedule_calendar_cal'][i]
    total_found_partial_schedule_calendar_cal += df['found_partial_schedule_calendar_cal'][i]
    total_found_extra_schedule_calendar_cal += df['found_extra_schedule_calendar_cal'][i]
print('WITH NOISE')
print('to find resource CALENDAR ctr          : ' + str(total_is_schedule_calendar_cal))
print('  found resource CALENDAR ctr (exact)  : ' + str(total_found_exact_schedule_calendar_cal) + '. Ratio is ' + str(total_found_exact_schedule_calendar_cal / total_is_schedule_calendar_cal))
print('  found resource CALENDAR ctr (partial): ' + str(total_found_partial_schedule_calendar_cal) + '. Ratio is ' + str(total_found_partial_schedule_calendar_cal / total_is_schedule_calendar_cal))
print('  found resource CALENDAR ctr (extra)  : ' + str(total_found_extra_schedule_calendar_cal) + '. Ratio is ' + str(total_found_extra_schedule_calendar_cal / total_is_schedule_calendar_cal))

total_is_schedule_calendar_cal = 0
total_found_exact_schedule_calendar_cal = 0
total_found_partial_schedule_calendar_cal = 0
total_found_extra_schedule_calendar_cal = 0

for i in range(0,len(df)):
  if df['nb_rows'][i] == 10:
    total_is_schedule_calendar_cal += df['is_schedule_calendar_cal'][i]
    total_found_exact_schedule_calendar_cal += df['found_exact_schedule_calendar_cal'][i]
    total_found_partial_schedule_calendar_cal += df['found_partial_schedule_calendar_cal'][i]
    total_found_extra_schedule_calendar_cal += df['found_extra_schedule_calendar_cal'][i]
print('Nb ROWS = 10')
print('to find resource CALENDAR ctr          : ' + str(total_is_schedule_calendar_cal))
print('  found resource CALENDAR ctr (exact)  : ' + str(total_found_exact_schedule_calendar_cal) + '. Ratio is ' + str(total_found_exact_schedule_calendar_cal / total_is_schedule_calendar_cal))
print('  found resource CALENDAR ctr (partial): ' + str(total_found_partial_schedule_calendar_cal) + '. Ratio is ' + str(total_found_partial_schedule_calendar_cal / total_is_schedule_calendar_cal))
print('  found resource CALENDAR ctr (extra)  : ' + str(total_found_extra_schedule_calendar_cal) + '. Ratio is ' + str(total_found_extra_schedule_calendar_cal / total_is_schedule_calendar_cal))

total_is_schedule_calendar_cal = 0
total_found_exact_schedule_calendar_cal = 0
total_found_partial_schedule_calendar_cal = 0
total_found_extra_schedule_calendar_cal = 0

for i in range(0,len(df)):
  if df['nb_rows'][i] == 100:
    total_is_schedule_calendar_cal += df['is_schedule_calendar_cal'][i]
    total_found_exact_schedule_calendar_cal += df['found_exact_schedule_calendar_cal'][i]
    total_found_partial_schedule_calendar_cal += df['found_partial_schedule_calendar_cal'][i]
    total_found_extra_schedule_calendar_cal += df['found_extra_schedule_calendar_cal'][i]
print('Nb ROWS = 100')
print('to find resource CALENDAR ctr          : ' + str(total_is_schedule_calendar_cal))
print('  found resource CALENDAR ctr (exact)  : ' + str(total_found_exact_schedule_calendar_cal) + '. Ratio is ' + str(total_found_exact_schedule_calendar_cal / total_is_schedule_calendar_cal))
print('  found resource CALENDAR ctr (partial): ' + str(total_found_partial_schedule_calendar_cal) + '. Ratio is ' + str(total_found_partial_schedule_calendar_cal / total_is_schedule_calendar_cal))
print('  found resource CALENDAR ctr (extra)  : ' + str(total_found_extra_schedule_calendar_cal) + '. Ratio is ' + str(total_found_extra_schedule_calendar_cal / total_is_schedule_calendar_cal))

total_is_schedule_calendar_cal = 0
total_found_exact_schedule_calendar_cal = 0
total_found_partial_schedule_calendar_cal = 0
total_found_extra_schedule_calendar_cal = 0

for i in range(0,len(df)):
  if df['nb_rows'][i] == 1000:
    total_is_schedule_calendar_cal += df['is_schedule_calendar_cal'][i]
    total_found_exact_schedule_calendar_cal += df['found_exact_schedule_calendar_cal'][i]
    total_found_partial_schedule_calendar_cal += df['found_partial_schedule_calendar_cal'][i]
    total_found_extra_schedule_calendar_cal += df['found_extra_schedule_calendar_cal'][i]
print('Nb ROWS = 1000')
print('to find resource CALENDAR ctr          : ' + str(total_is_schedule_calendar_cal))
print('  found resource CALENDAR ctr (exact)  : ' + str(total_found_exact_schedule_calendar_cal) + '. Ratio is ' + str(total_found_exact_schedule_calendar_cal / total_is_schedule_calendar_cal))
print('  found resource CALENDAR ctr (partial): ' + str(total_found_partial_schedule_calendar_cal) + '. Ratio is ' + str(total_found_partial_schedule_calendar_cal / total_is_schedule_calendar_cal))
print('  found resource CALENDAR ctr (extra)  : ' + str(total_found_extra_schedule_calendar_cal) + '. Ratio is ' + str(total_found_extra_schedule_calendar_cal / total_is_schedule_calendar_cal))

total_is_schedule_calendar_cal = 0
total_found_exact_schedule_calendar_cal = 0
total_found_partial_schedule_calendar_cal = 0
total_found_extra_schedule_calendar_cal = 0

for i in range(0,len(df)):
  if df['nb_rows'][i] == 10000:
    total_is_schedule_calendar_cal += df['is_schedule_calendar_cal'][i]
    total_found_exact_schedule_calendar_cal += df['found_exact_schedule_calendar_cal'][i]
    total_found_partial_schedule_calendar_cal += df['found_partial_schedule_calendar_cal'][i]
    total_found_extra_schedule_calendar_cal += df['found_extra_schedule_calendar_cal'][i]
print('Nb ROWS = 10000')
print('to find resource CALENDAR ctr          : ' + str(total_is_schedule_calendar_cal))
print('  found resource CALENDAR ctr (exact)  : ' + str(total_found_exact_schedule_calendar_cal) + '. Ratio is ' + str(total_found_exact_schedule_calendar_cal / total_is_schedule_calendar_cal))
print('  found resource CALENDAR ctr (partial): ' + str(total_found_partial_schedule_calendar_cal) + '. Ratio is ' + str(total_found_partial_schedule_calendar_cal / total_is_schedule_calendar_cal))
print('  found resource CALENDAR ctr (extra)  : ' + str(total_found_extra_schedule_calendar_cal) + '. Ratio is ' + str(total_found_extra_schedule_calendar_cal / total_is_schedule_calendar_cal))
# Out:
# ALL DATA
# to find resource CALENDAR ctr          : 15840
#   found resource CALENDAR ctr (exact)  : 15558. Ratio is 0.9821969696969697
#   found resource CALENDAR ctr (partial): 4. Ratio is 0.0002525252525252525
#   found resource CALENDAR ctr (extra)  : 0. Ratio is 0.0
# WITHOUT NOISE
# to find resource CALENDAR ctr          : 7920
#   found resource CALENDAR ctr (exact)  : 7726. Ratio is 0.9755050505050505
#   found resource CALENDAR ctr (partial): 0. Ratio is 0.0
#   found resource CALENDAR ctr (extra)  : 0. Ratio is 0.0
# WITH NOISE
# to find resource CALENDAR ctr          : 7920
#   found resource CALENDAR ctr (exact)  : 7832. Ratio is 0.9888888888888889
#   found resource CALENDAR ctr (partial): 4. Ratio is 0.000505050505050505
#   found resource CALENDAR ctr (extra)  : 0. Ratio is 0.0
# Nb ROWS = 10
# to find resource CALENDAR ctr          : 3960
#   found resource CALENDAR ctr (exact)  : 3741. Ratio is 0.9446969696969697
# ...

# %%
# 'found_formula_exact_end_time', 'found_formula_partial_end_time',
# 'found_formula_exact_duration', 'found_formula_partial_duration',
# 'found_extra_formulae',

total_is_formula_duration = 0
total_found_exact_formula_duration = 0
total_found_partial_formula_duration = 0
total_found_extra_formulae_duration = 0
total_is_formula_end_time = 0
total_found_exact_formula_end_time = 0
total_found_partial_formula_end_time = 0
total_found_extra_formulae_end_time = 0

for i in range(0,len(df)):
  total_is_formula_duration += df['is_formula_duration'][i]
  total_found_exact_formula_duration += df['found_formula_exact_duration'][i]
  total_found_partial_formula_duration += df['found_formula_partial_duration'][i]
  total_found_extra_formulae_duration += df['found_extra_formulae_duration'][i]
  total_is_formula_end_time += df['is_formula_end_time'][i]
  total_found_exact_formula_end_time += df['found_formula_exact_end_time'][i]
  total_found_partial_formula_end_time += df['found_formula_partial_end_time'][i]
  total_found_extra_formulae_end_time += df['found_extra_formulae_end_time'][i]
print('ALL DATA')
print('to find duration ctr: ' + str(total_is_formula_duration))
print(' found   exact duration ctr: ' + str(total_found_exact_formula_duration) + '. Ratio is ' + str(total_found_exact_formula_duration / total_is_formula_duration))
print(' found partial duration ctr: ' + str(total_found_partial_formula_duration) + '. Ratio is ' + str(total_found_partial_formula_duration / total_is_formula_duration))
print(' found extra duration formula ctr: ' + str(total_found_extra_formulae_duration) + '. Ratio is ' + str(total_found_extra_formulae_duration / total_is_formula_duration))
print('to find end_time ctr: ' + str(total_is_formula_end_time))
print(' found   exact end_time ctr: ' + str(total_found_exact_formula_end_time) + '. Ratio is ' + str(total_found_exact_formula_end_time / total_is_formula_end_time))
print(' found partial end_time ctr: ' + str(total_found_partial_formula_end_time) + '. Ratio is ' + str(total_found_partial_formula_end_time / total_is_formula_end_time))
print(' found extra end_time formula ctr: ' + str(total_found_extra_formulae_end_time) + '. Ratio is ' + str(total_found_extra_formulae_end_time / total_is_formula_end_time))

total_is_formula_duration = 0
total_found_exact_formula_duration = 0
total_found_partial_formula_duration = 0
total_found_extra_formulae_duration = 0
total_is_formula_end_time = 0
total_found_exact_formula_end_time = 0
total_found_partial_formula_end_time = 0
total_found_extra_formulae_end_time = 0

for i in range(0,len(df)):
  if df['nb_rows'][i] == 10:
    total_is_formula_duration += df['is_formula_duration'][i]
    total_found_exact_formula_duration += df['found_formula_exact_duration'][i]
    total_found_partial_formula_duration += df['found_formula_partial_duration'][i]
    total_found_extra_formulae_duration += df['found_extra_formulae_duration'][i]
    total_is_formula_end_time += df['is_formula_end_time'][i]
    total_found_exact_formula_end_time += df['found_formula_exact_end_time'][i]
    total_found_partial_formula_end_time += df['found_formula_partial_end_time'][i]
    total_found_extra_formulae_end_time += df['found_extra_formulae_end_time'][i]
print('Nb ROWS = 10')
print('to find duration ctr: ' + str(total_is_formula_duration))
print(' found   exact duration ctr: ' + str(total_found_exact_formula_duration) + '. Ratio is ' + str(total_found_exact_formula_duration / total_is_formula_duration))
print(' found partial duration ctr: ' + str(total_found_partial_formula_duration) + '. Ratio is ' + str(total_found_partial_formula_duration / total_is_formula_duration))
print(' found extra duration formula ctr: ' + str(total_found_extra_formulae_duration) + '. Ratio is ' + str(total_found_extra_formulae_duration / total_is_formula_duration))
print('to find end_time ctr: ' + str(total_is_formula_end_time))
print(' found   exact end_time ctr: ' + str(total_found_exact_formula_end_time) + '. Ratio is ' + str(total_found_exact_formula_end_time / total_is_formula_end_time))
print(' found partial end_time ctr: ' + str(total_found_partial_formula_end_time) + '. Ratio is ' + str(total_found_partial_formula_end_time / total_is_formula_end_time))
print(' found extra end_time formula ctr: ' + str(total_found_extra_formulae_end_time) + '. Ratio is ' + str(total_found_extra_formulae_end_time / total_is_formula_end_time))

total_is_formula_duration = 0
total_found_exact_formula_duration = 0
total_found_partial_formula_duration = 0
total_found_extra_formulae_duration = 0
total_is_formula_end_time = 0
total_found_exact_formula_end_time = 0
total_found_partial_formula_end_time = 0
total_found_extra_formulae_end_time = 0

for i in range(0,len(df)):
  if df['nb_rows'][i] == 100:
    total_is_formula_duration += df['is_formula_duration'][i]
    total_found_exact_formula_duration += df['found_formula_exact_duration'][i]
    total_found_partial_formula_duration += df['found_formula_partial_duration'][i]
    total_found_extra_formulae_duration += df['found_extra_formulae_duration'][i]
    total_is_formula_end_time += df['is_formula_end_time'][i]
    total_found_exact_formula_end_time += df['found_formula_exact_end_time'][i]
    total_found_partial_formula_end_time += df['found_formula_partial_end_time'][i]
    total_found_extra_formulae_end_time += df['found_extra_formulae_end_time'][i]
print('Nb ROWS = 100')
print('to find duration ctr: ' + str(total_is_formula_duration))
print(' found   exact duration ctr: ' + str(total_found_exact_formula_duration) + '. Ratio is ' + str(total_found_exact_formula_duration / total_is_formula_duration))
print(' found partial duration ctr: ' + str(total_found_partial_formula_duration) + '. Ratio is ' + str(total_found_partial_formula_duration / total_is_formula_duration))
print(' found extra duration formula ctr: ' + str(total_found_extra_formulae_duration) + '. Ratio is ' + str(total_found_extra_formulae_duration / total_is_formula_duration))
print('to find end_time ctr: ' + str(total_is_formula_end_time))
print(' found   exact end_time ctr: ' + str(total_found_exact_formula_end_time) + '. Ratio is ' + str(total_found_exact_formula_end_time / total_is_formula_end_time))
print(' found partial end_time ctr: ' + str(total_found_partial_formula_end_time) + '. Ratio is ' + str(total_found_partial_formula_end_time / total_is_formula_end_time))
print(' found extra end_time formula ctr: ' + str(total_found_extra_formulae_end_time) + '. Ratio is ' + str(total_found_extra_formulae_end_time / total_is_formula_end_time))

total_is_formula_duration = 0
total_found_exact_formula_duration = 0
total_found_partial_formula_duration = 0
total_found_extra_formulae_duration = 0
total_is_formula_end_time = 0
total_found_exact_formula_end_time = 0
total_found_partial_formula_end_time = 0
total_found_extra_formulae_end_time = 0

for i in range(0,len(df)):
  if df['nb_rows'][i] == 1000:
    total_is_formula_duration += df['is_formula_duration'][i]
    total_found_exact_formula_duration += df['found_formula_exact_duration'][i]
    total_found_partial_formula_duration += df['found_formula_partial_duration'][i]
    total_found_extra_formulae_duration += df['found_extra_formulae_duration'][i]
    total_is_formula_end_time += df['is_formula_end_time'][i]
    total_found_exact_formula_end_time += df['found_formula_exact_end_time'][i]
    total_found_partial_formula_end_time += df['found_formula_partial_end_time'][i]
    total_found_extra_formulae_end_time += df['found_extra_formulae_end_time'][i]
print('Nb ROWS = 1000')
print('to find duration ctr: ' + str(total_is_formula_duration))
print(' found   exact duration ctr: ' + str(total_found_exact_formula_duration) + '. Ratio is ' + str(total_found_exact_formula_duration / total_is_formula_duration))
print(' found partial duration ctr: ' + str(total_found_partial_formula_duration) + '. Ratio is ' + str(total_found_partial_formula_duration / total_is_formula_duration))
print(' found extra duration formula ctr: ' + str(total_found_extra_formulae_duration) + '. Ratio is ' + str(total_found_extra_formulae_duration / total_is_formula_duration))
print('to find end_time ctr: ' + str(total_is_formula_end_time))
print(' found   exact end_time ctr: ' + str(total_found_exact_formula_end_time) + '. Ratio is ' + str(total_found_exact_formula_end_time / total_is_formula_end_time))
print(' found partial end_time ctr: ' + str(total_found_partial_formula_end_time) + '. Ratio is ' + str(total_found_partial_formula_end_time / total_is_formula_end_time))
print(' found extra end_time formula ctr: ' + str(total_found_extra_formulae_end_time) + '. Ratio is ' + str(total_found_extra_formulae_end_time / total_is_formula_end_time))

total_is_formula_duration = 0
total_found_exact_formula_duration = 0
total_found_partial_formula_duration = 0
total_found_extra_formulae_duration = 0
total_is_formula_end_time = 0
total_found_exact_formula_end_time = 0
total_found_partial_formula_end_time = 0
total_found_extra_formulae_end_time = 0

for i in range(0,len(df)):
  if df['nb_rows'][i] == 10000:
    total_is_formula_duration += df['is_formula_duration'][i]
    total_found_exact_formula_duration += df['found_formula_exact_duration'][i]
    total_found_partial_formula_duration += df['found_formula_partial_duration'][i]
    total_found_extra_formulae_duration += df['found_extra_formulae_duration'][i]
    total_is_formula_end_time += df['is_formula_end_time'][i]
    total_found_exact_formula_end_time += df['found_formula_exact_end_time'][i]
    total_found_partial_formula_end_time += df['found_formula_partial_end_time'][i]
    total_found_extra_formulae_end_time += df['found_extra_formulae_end_time'][i]
print('Nb ROWS = 10000')
print('to find duration ctr: ' + str(total_is_formula_duration))
print(' found   exact duration ctr: ' + str(total_found_exact_formula_duration) + '. Ratio is ' + str(total_found_exact_formula_duration / total_is_formula_duration))
print(' found partial duration ctr: ' + str(total_found_partial_formula_duration) + '. Ratio is ' + str(total_found_partial_formula_duration / total_is_formula_duration))
print(' found extra duration formula ctr: ' + str(total_found_extra_formulae_duration) + '. Ratio is ' + str(total_found_extra_formulae_duration / total_is_formula_duration))
print('to find end_time ctr: ' + str(total_is_formula_end_time))
print(' found   exact end_time ctr: ' + str(total_found_exact_formula_end_time) + '. Ratio is ' + str(total_found_exact_formula_end_time / total_is_formula_end_time))
print(' found partial end_time ctr: ' + str(total_found_partial_formula_end_time) + '. Ratio is ' + str(total_found_partial_formula_end_time / total_is_formula_end_time))
print(' found extra end_time formula ctr: ' + str(total_found_extra_formulae_end_time) + '. Ratio is ' + str(total_found_extra_formulae_end_time / total_is_formula_end_time))
# Out:
# ALL DATA
# to find duration ctr: 16240
#  found   exact duration ctr: 14602. Ratio is 0.8991379310344828
#  found partial duration ctr: 725. Ratio is 0.044642857142857144
#  found extra duration formula ctr: 76. Ratio is 0.004679802955665025
# to find end_time ctr: 23680
#  found   exact end_time ctr: 21378. Ratio is 0.9027871621621621
#  found partial end_time ctr: 1743. Ratio is 0.07360641891891892
#  found extra end_time formula ctr: 1. Ratio is 4.222972972972973e-05
# Nb ROWS = 10
# to find duration ctr: 4060
#  found   exact duration ctr: 2697. Ratio is 0.6642857142857143
#  found partial duration ctr: 725. Ratio is 0.17857142857142858
#  found extra duration formula ctr: 76. Ratio is 0.0187192118226601
# to find end_time ctr: 5920
#  found   exact end_time ctr: 4801. Ratio is 0.8109797297297298
#  found partial end_time ctr: 714. Ratio is 0.12060810810810811
#  found extra end_time formula ctr: 1. Ratio is 0.00016891891891891893
# Nb ROWS = 100
# to find duration ctr: 4060
# ...

# %%
total_is_formula_duration = 0
total_found_exact_formula_duration = 0
total_found_partial_formula_duration = 0
total_found_extra_formulae_duration = 0
total_is_formula_end_time = 0
total_found_exact_formula_end_time = 0
total_found_partial_formula_end_time = 0
total_found_extra_formulae_end_time = 0

for i in range(0,len(df)):
  total_is_formula_duration += df['is_formula_duration'][i]
  total_found_exact_formula_duration += df['found_formula_exact_duration'][i]
  total_found_partial_formula_duration += df['found_formula_partial_duration'][i]
  total_found_extra_formulae_duration += df['found_extra_formulae_duration'][i]
  total_is_formula_end_time += df['is_formula_end_time'][i]
  total_found_exact_formula_end_time += df['found_formula_exact_end_time'][i]
  total_found_partial_formula_end_time += df['found_formula_partial_end_time'][i]
  total_found_extra_formulae_end_time += df['found_extra_formulae_end_time'][i]
print('ALL DATA')
print('to find duration ctr: ' + str(total_is_formula_duration))
print(' found   exact duration ctr: ' + str(total_found_exact_formula_duration) + '. Ratio is ' + str(total_found_exact_formula_duration / total_is_formula_duration))
print(' found partial duration ctr: ' + str(total_found_partial_formula_duration) + '. Ratio is ' + str(total_found_partial_formula_duration / total_is_formula_duration))
print(' found extra duration formula ctr: ' + str(total_found_extra_formulae_duration) + '. Ratio is ' + str(total_found_extra_formulae_duration / total_is_formula_duration))
print('to find end_time ctr: ' + str(total_is_formula_end_time))
print(' found   exact end_time ctr: ' + str(total_found_exact_formula_end_time) + '. Ratio is ' + str(total_found_exact_formula_end_time / total_is_formula_end_time))
print(' found partial end_time ctr: ' + str(total_found_partial_formula_end_time) + '. Ratio is ' + str(total_found_partial_formula_end_time / total_is_formula_end_time))
print(' found extra end_time formula ctr: ' + str(total_found_extra_formulae_end_time) + '. Ratio is ' + str(total_found_extra_formulae_end_time / total_is_formula_end_time))

total_is_formula_duration = 0
total_found_exact_formula_duration = 0
total_found_partial_formula_duration = 0
total_found_extra_formulae_duration = 0
total_is_formula_end_time = 0
total_found_exact_formula_end_time = 0
total_found_partial_formula_end_time = 0
total_found_extra_formulae_end_time = 0

for i in range(0,len(df)):
  if df['noise_columns'][i] == 0:
    total_is_formula_duration += df['is_formula_duration'][i]
    total_found_exact_formula_duration += df['found_formula_exact_duration'][i]
    total_found_partial_formula_duration += df['found_formula_partial_duration'][i]
    total_found_extra_formulae_duration += df['found_extra_formulae_duration'][i]
    total_is_formula_end_time += df['is_formula_end_time'][i]
    total_found_exact_formula_end_time += df['found_formula_exact_end_time'][i]
    total_found_partial_formula_end_time += df['found_formula_partial_end_time'][i]
    total_found_extra_formulae_end_time += df['found_extra_formulae_end_time'][i]
print('WITHOUT NOISE')
print('to find duration ctr: ' + str(total_is_formula_duration))
print(' found   exact duration ctr: ' + str(total_found_exact_formula_duration) + '. Ratio is ' + str(total_found_exact_formula_duration / total_is_formula_duration))
print(' found partial duration ctr: ' + str(total_found_partial_formula_duration) + '. Ratio is ' + str(total_found_partial_formula_duration / total_is_formula_duration))
print(' found extra duration formula ctr: ' + str(total_found_extra_formulae_duration) + '. Ratio is ' + str(total_found_extra_formulae_duration / total_is_formula_duration))
print('to find end_time ctr: ' + str(total_is_formula_end_time))
print(' found   exact end_time ctr: ' + str(total_found_exact_formula_end_time) + '. Ratio is ' + str(total_found_exact_formula_end_time / total_is_formula_end_time))
print(' found partial end_time ctr: ' + str(total_found_partial_formula_end_time) + '. Ratio is ' + str(total_found_partial_formula_end_time / total_is_formula_end_time))
print(' found extra end_time formula ctr: ' + str(total_found_extra_formulae_end_time) + '. Ratio is ' + str(total_found_extra_formulae_end_time / total_is_formula_end_time))

total_is_formula_duration = 0
total_found_exact_formula_duration = 0
total_found_partial_formula_duration = 0
total_found_extra_formulae_duration = 0
total_is_formula_end_time = 0
total_found_exact_formula_end_time = 0
total_found_partial_formula_end_time = 0
total_found_extra_formulae_end_time = 0

for i in range(0,len(df)):
  if df['noise_columns'][i] == 1:
    total_is_formula_duration += df['is_formula_duration'][i]
    total_found_exact_formula_duration += df['found_formula_exact_duration'][i]
    total_found_partial_formula_duration += df['found_formula_partial_duration'][i]
    total_found_extra_formulae_duration += df['found_extra_formulae_duration'][i]
    total_is_formula_end_time += df['is_formula_end_time'][i]
    total_found_exact_formula_end_time += df['found_formula_exact_end_time'][i]
    total_found_partial_formula_end_time += df['found_formula_partial_end_time'][i]
    total_found_extra_formulae_end_time += df['found_extra_formulae_end_time'][i]
print('WITH NOISE')
print('to find duration ctr: ' + str(total_is_formula_duration))
print(' found   exact duration ctr: ' + str(total_found_exact_formula_duration) + '. Ratio is ' + str(total_found_exact_formula_duration / total_is_formula_duration))
print(' found partial duration ctr: ' + str(total_found_partial_formula_duration) + '. Ratio is ' + str(total_found_partial_formula_duration / total_is_formula_duration))
print(' found extra duration formula ctr: ' + str(total_found_extra_formulae_duration) + '. Ratio is ' + str(total_found_extra_formulae_duration / total_is_formula_duration))
print('to find end_time ctr: ' + str(total_is_formula_end_time))
print(' found   exact end_time ctr: ' + str(total_found_exact_formula_end_time) + '. Ratio is ' + str(total_found_exact_formula_end_time / total_is_formula_end_time))
print(' found partial end_time ctr: ' + str(total_found_partial_formula_end_time) + '. Ratio is ' + str(total_found_partial_formula_end_time / total_is_formula_end_time))
print(' found extra end_time formula ctr: ' + str(total_found_extra_formulae_end_time) + '. Ratio is ' + str(total_found_extra_formulae_end_time / total_is_formula_end_time))
# Out:
# ALL DATA
# to find duration ctr: 16240
#  found   exact duration ctr: 14602. Ratio is 0.8991379310344828
#  found partial duration ctr: 725. Ratio is 0.044642857142857144
#  found extra duration formula ctr: 76. Ratio is 0.004679802955665025
# to find end_time ctr: 23680
#  found   exact end_time ctr: 21378. Ratio is 0.9027871621621621
#  found partial end_time ctr: 1743. Ratio is 0.07360641891891892
#  found extra end_time formula ctr: 1. Ratio is 4.222972972972973e-05
# WITHOUT NOISE
# to find duration ctr: 8120
#  found   exact duration ctr: 7205. Ratio is 0.8873152709359606
#  found partial duration ctr: 418. Ratio is 0.05147783251231527
#  found extra duration formula ctr: 60. Ratio is 0.007389162561576354
# to find end_time ctr: 11840
#  found   exact end_time ctr: 10673. Ratio is 0.9014358108108108
#  found partial end_time ctr: 939. Ratio is 0.07930743243243243
#  found extra end_time formula ctr: 0. Ratio is 0.0
# WITH NOISE
# to find duration ctr: 8120
# ...

# %%
1 in [1,2,3]
# Out:
# True
